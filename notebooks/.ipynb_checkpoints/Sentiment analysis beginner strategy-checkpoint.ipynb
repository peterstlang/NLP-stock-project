# %% [markdown]
# # Testing an approach
# Found an article I would like to try out on my ms title/article dataset. Link can be found here: https://algotrading101.com/learn/sentiment-analysis-python-guide/

# %% [markdown]
# #### Reading data from file

# %%
# imports
import pandas as pd
# Out:
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# loading data
df = pd.read_csv("C:/Users/peter/Documents/NLP-stock-project/data/news_headlines.csv")
df.head()
# Out:
#                                                Title  \
# 0  The national security dimension of OpenAI's le...
# 1  OpenAI staff threaten mass exodus to join ex-C...
# 2  Sam Altman, ex OpenAI founder and CEO now at M...
# 3  BLUETTI Launches Black Friday Sale On Battery ...
# 4  What led to the OpenAI leadership shakeup and ...
#
#                                          Description          Source  \
# 0  Published on November 20, 2023 11:57 PM GMTAs ...   Lesswrong.com
# 1  SAN FRANCISCO: Hundreds of staff at OpenAI thr...             CNA
# 2  Microsoft has hired Sam Altman, where he will ...       TweakTown
# 3  Running out of power is nobody's idea of fun b...  redmondpie.com
# 4  Microsoft announced that it hired Sam Altman, ...      Biztoc.com
#
#            Published At
# 0  2023-11-20T23:57:17Z
# 1  2023-11-20T23:55:54Z
# 2  2023-11-20T23:55:02Z
# 3  2023-11-20T23:54:50Z
# 4  2023-11-20T23:54:06Z

# %%
df.shape
# Out:
# (400, 4)

# %%
#import
from langdetect import detect

# Adding a language column
df["Language"] = df["Title"].apply(lambda x: detect(x))
# Keeping only rows where lang is en
df = df.drop(df[df.Language != "en"].index)
df = df.drop("Language", axis=1)

# clean PublishedAt column
df["Published At"] = pd.to_datetime(df["Published At"], format="%Y-%m-%dT%H:%M:%SZ")

df.head()
# Out:
#                                                Title  \
# 0  The national security dimension of OpenAI's le...
# 1  OpenAI staff threaten mass exodus to join ex-C...
# 2  Sam Altman, ex OpenAI founder and CEO now at M...
# 3  BLUETTI Launches Black Friday Sale On Battery ...
# 4  What led to the OpenAI leadership shakeup and ...
#
#                                          Description          Source  \
# 0  Published on November 20, 2023 11:57 PM GMTAs ...   Lesswrong.com
# 1  SAN FRANCISCO: Hundreds of staff at OpenAI thr...             CNA
# 2  Microsoft has hired Sam Altman, where he will ...       TweakTown
# 3  Running out of power is nobody's idea of fun b...  redmondpie.com
# 4  Microsoft announced that it hired Sam Altman, ...      Biztoc.com
#
#          Published At
# 0 2023-11-20 23:57:17
# 1 2023-11-20 23:55:54
# 2 2023-11-20 23:55:02
# 3 2023-11-20 23:54:50
# 4 2023-11-20 23:54:06

# %%
# WHY IS DATA NOT PULLED AND SAVED?
# IT IS!
df.shape
# Out:
# (354, 4)

# %%
print("from {0} to {1}".format(min(df["Published At"]), max(df["Published At"])))
# Out:
# from 2023-11-20 22:08:01 to 2023-11-26 23:47:21

# %%
for title in df["Title"]:
    print(title)
# Out:
# The national security dimension of OpenAI's leadership struggle
# OpenAI staff threaten mass exodus to join ex-CEO Sam Altman at Microsoft
# Sam Altman, ex OpenAI founder and CEO now at Microsoft to run new advanced AI intelligence team
# BLUETTI Launches Black Friday Sale On Battery Packs and A New Power Station
# What led to the OpenAI leadership shakeup and what it means for the future of AI
# Is Sam Altman joining Microsoft? Satya Nadella doesn’t seem to know
# Sam Altman’s OpenAI exit won’t stop the use of ChatGPT among crypto devs, at least for now
# Best free Language Translation websites
# Microsoft’s Nadella: OpenAI’s Governance Needs to Change
# How Microsoft’s Satya Nadella Kept the ‘Best Bromance in Tech’ Alive
# The Slatest for Nov. 20: Sam Altman’s Firing Is Just the First Skirmish in a War Over A.I.
# What’s next for the artificial intelligence industry?
# What led to the OpenAI leadership shakeup and what it means for the future of AI
# Kindle Scribe vs reMarkable 2: Which should you buy?
# Microsoft's Nadella: OpenAI's Governance Needs to Change
# Cramer says mergers and acquisitions could be the ‘potential savior’ for much of the market
# WLD Had a Wild Weekend—What's Next for Sam Altman's Worldcoin?
# Sam Altman says successful people ‘believe in themselves almost to the point of delusion’ —that's frightening, says expert
# Why OpenAI’s board ousted CEO Sam Altman and the fallout, explained
# Microsoft CEO says OpenAI governance needs to change no matter where Sam Altman ends up
# Sam Altman claims ‘still one team’ at OpenAI as investors, employees revolt over his ouster
# AI doomsayers blamed in OpenAI’s undoing
# The idea of OpenAI is dead. Now Microsoft is in the driver’s seat
# Court seems inclined to keep restricting Trump's trial speech. But gag order could be narrowed
# Microsoft CEO says OpenAI governance needs to change no matter where Sam Altman ends up
# Microsoft stock hits all-time high after hiring OpenAI’s fired CEO Sam Altman
# Sam Altman to join Microsoft research team after OpenAI ousts him. Here's what we know
# HP Pavilion TP01-3016 Desktop Computer, Intel Core i5-12400, 12GB Memory, 256GB SSD $389.99
# OpenAI's loss is Microsoft's gain: How the AI race just changed
# Microsoft CEO Nadella says OpenAI governance needs to change no matter where Altman ends up
# OpenAI's employees were given two explanations for why Sam Altman was fired. They're unconvinced and furious.
# Microsoft Hires Sam Altman as OpenAI's New CEO Vows to Investigate Firing
# OpenAI Investors Considering Suing Board After CEO's Firing: Sources
# Scattered Spider ransomware gang falls under government agency scrutiny
# OpenAI’s wild 60 hours: Here’s what happened
# Satya Nadella says “it's very clear that something has to change around the governance” of OpenAI no matter where Sam Altman ends up
# Microsoft CEO Nadella says OpenAI governance needs to change no matter where Altman ends up
# Microsoft is the only real winner in the OpenAI debacle
# How Music and Radio Played a Role During the American Indian Occupation of Alcatraz
# The Schism That Toppled Sam Altman
# The Good, Bad, And Ugly From Supercomputing ‘23, Or Nearby
# Microsoft CEO Nadella Says OpenAI Governance Needs To Change No Matter Where Altman Ends Up - CNBC
# Salesforce CEO Offers Jobs To Any OpenAI Researchers Who Resign
# 'Segregating high skill players from the population at large, forcing long wait times on them, is a form of discrimination': former Halo multiplayer lead on the 'failure' of SBMM in modern games
# OpenAI Turmoil Leaves Some CIOs Questioning the AI Powerhouse’s Future
# [Refurb] Microsoft Surface Laptop 2 i5 8th Gen 8Gb Ram 256Gb SSD $299 Delivered @ Australian Computer Traders
# The Microsoft Black Friday Ad Has Arrived: Save Hundreds on Surface Devices
# The Microsoft Black Friday Ad Has Arrived: Save Hundreds on Surface Devices
# Exclusive-OpenAI investors considering suing the board after CEO's abrupt firing - sources
# Exclusive-OpenAI investors considering suing the board after CEO's abrupt firing - sources
# Exclusive-OpenAI investors considering suing the board after CEO's abrupt firing - sources
# Why you should care about Sam Altman, Microsoft, and the OpenAI CEO mess
# Windows 10 22H2 Insider Release Preview Build 19045.3757 begins Copilot rollout
# OpenAI investors considering suing the board after CEO's abrupt firing: Sources
# Catch up on the OpenAI’s wild 60 hours… in 60 seconds | CNN Business
# Former Twitch CEO Emmett Shear is now leading OpenAI
# OpenAI investors considering suing the board after CEO's abrupt firing - sources
# Stock market news today: S&P 500, Nasdaq hit highest level since August as Nvidia, Microsoft reach records
# Marketmind: Rallying Nikkei on the cusp of a breakout
# Microsoft Advertising Shares Holiday Season Marketing Playbook via @sejournal, @kristileilani
# Satya Nadella And Microsoft Are The Biggest Winners Of The OpenAI Meltdown
# AI Doomsayers Blamed In OpenAI's Undoing
# Satya Nadella added $63 billion in market value for Microsoft with a ‘poker move for the ages’
# Israel battles Hamas near another Gaza hospital sheltering thousands
# Salesforce CEO Offers Jobs To Any OpenAI Researchers Who Resign
# Retro blinkenlights: driving 4 charlieplex LED matrices #AdafruitPlayground #FeaturedNote @Adafruit
# Microsoft CEO expected to negotiate stability at OpenAI and keep teams intact
# Why OpenAI blew up — and why it matters
# OpenAI’s new CEO Emmett Shear: AI is so dangerous, ‘it should cause you to s–t your pants’
# Don't expect competition authorities to wade into the Microsoft-OpenAI power-play -- yet | TechCrunch
# What’s going on with OpenAI now that Sam Altman is out?
# Washington watches as West Coast nerds fight for future of AI
# Sam Altman’s Move to Microsoft Changes Its Bing Search Battle With Google
# KB5033288: Following 23H2 and 22H2, Windows 11 21H2 gets improved WinRE as well
# US stocks jump as bond yields slip and Microsoft shares surge
# What to know about new OpenAI interim CEO Emmett Shear
# Analyst reaction to OpenAI turmoil: Shrewd move by Microsoft
# OpenAI won the battle, but it may have lost the war
# OpenAI, Microsoft hit with new author copyright lawsuit over AI training
# Former OpenAI Employees Allege “Deceit and Manipulation” by Sam Altman: Elon Musk Calls for Investigation
# Bypass Paywalls Clean combines all soft paywall hacks into one neat package
# OpenAI won the battle, but it may have lost the war
# Microsoft Introduces Azure Boost to redefine cloud computing
# Ubisoft has 'paused' advertising on Twitter
# It’s over: OpenAI reaches agreement ‘in principle’ for Sam Altman to return as CEO, with new board
# Despite Microsoft job offer, Sam Altman continues to negotiate with OpenAI board over possible reinstatement
# Chaos in the Cradle of A.I.
# Nvidia’s Revenues Tripled in Q3
# Nvidia’s Sales Surge, With No End In Sight for AI Boom
# Black Friday 2023 laptop deals from Dell, HP, Lenovo, Apple, Microsoft, and more - Ars Technica
# New Lawsuit Ropes Microsoft Into OpenAI’s Legal Battle With Authors Over Training Data
# Wow: Sam Altman fired, joins Microsoft, now OpenAI board talking about his return
# Will Artificial Intelligence Totally Transform Culture & Intellectual Work? An Engineer & an Author Debate. Part 1, Music & Movies
# A timeline of Sam Altman's firing from OpenAI -- and the fallout | TechCrunch
# Microsoft Xbox Series S - CNET
# OpenAI's unusual nonprofit structure led to dramatic ouster of sought-after CEO
# Nvidia Fails to Satisfy Lofty Investor Expectations for AI Boom
# Indigenous Artists from the Four Corner States
# Sam Altman, OpenAI board open talks to negotiate his possible return
# Microsoft preparing San Francisco offices for OpenAI employees, even as chaos lingers
# Black Friday 2023 laptop deals from Dell, HP, Lenovo, Apple, Microsoft, and more
# Martello Technologies Group Inc. Reports Earnings Results for the Second Quarter and Six Months Ended September 30, 2023
# Futures: Nvidia EPS Skyrockets Again; Is It Enough?
# 95% of OpenAI employees have threatened to quit in standoff with board
# Dell Inspiron 15 3520 11th-Gen i5 15.6" Touch Laptop for $380 + free shipping
# The Twists And Turns Of An OpenAI Meltdown
# Service Included, FinOps Foundation Counts Cost Of Cloud
# The twists and turns of an OpenAI meltdown
# Ex-OpenAI president Greg Brockman announces ChatGPT voice support now open to all
# Dow Jones Futures: Nvidia Earnings Skyrocket Again On AI Boom, But Is It Enough?
# Ex-OpenAI staff launch new chatbot – yup, it's Anthropic with Claude 2.1
# OpenAI's board may be coming around to Sam Altman returning | TechCrunch
# HP Omen 13th-Gen i7 16.1" Laptop w/ NVIDIA GeForce RTX 4050 for $1,000 + free shipping
# Greg Brockman is still announcing OpenAI products for some reason
# Spotify reaches special deal with Google to waive Play Store commission
# Where OpenAI goes from here is anyone’s guess
# OpenAI launches free ChatGPT Voice because it’s not like anything else important was going on
# OpenAI's unusual nonprofit structure led to dramatic ouster of sought-after CEO
# Sam Altman’s ousting from OpenAI could lead to even greater success: ‘You could parachute him into an island full of cannibals and come back in five years and…
# OpenAI drops a big new ChatGPT feature with a joke about its CEO drama
# Udemy Free Courses for a limited time
# Twitter Is in Extremely Deep Trouble
# Sam Altman’s ousting from OpenAI could lead to even greater success: ‘You could parachute him into an island full of cannibals and come back in five years and he’d be the king’
# OpenAI and Silicon Valley’s new era of personal rule
# Commentary: From OpenAI to Microsoft, Sam Altman exposes the charade of AI accountability
# Of course its preregistered. Just give me a sec
# OpenAI board acted in totally haphazard way: Legal tech expert
# Report: OpenAI Board in Talks With Sam Altman
# Microsoft preparing San Francisco offices for OpenAI employees, even as chaos lingers
# Teen Vogue Summit 2023 Gives Advice on Being an Influencer, Getting Politically Engaged, and More
# OpenAI, Microsoft Hit With New Author Copyright Lawsuit Over AI Training
# Nvidia forecasts fourth-quarter revenue above estimates
# OpenAI's Board May Be Coming Around To Sam Altman Returning
# As AI-Controlled Killer Drones Become Reality, Nations Debate Limits...
# OpenAI's Board May Be Coming Around To Sam Altman Returning
# OpenAI's unusual nonprofit structure led to dramatic ouster of sought-after CEO
# ENow Introduces New Security Software to Address Microsoft Entra ID Application Governance Challenges
# OpenAI's unusual nonprofit structure led to dramatic ouster of sought-after CEO
# CEO of Fortnite game maker casts Google as 'crooked' bully in testimony during Android app trial
# Microsoft Preps to Welcome OpenAI Staffers Threatening to Jump Ship: Report
# Tutorial: Make an LED Scrolling Sign and Update it via Text Message SMS
# OpenAI Board Seeks Leadership Change and Merger
# Exploit for Critical Windows Defender Bypass Goes Public
# Greg Brockman is still announcing OpenAI products for some reason
# Sam Altman ouster spotlights rift over extinction threat posed by AI
# OpenAI's unusual nonprofit structure led to dramatic ouster of sought-after CEO
# What’s happening at OpenAI? A look at Sam Altman’s firing, his new role at Microsoft and more
# Nvidia Earnings: Record Quarterly Revenue, Profits For Second Straight Quarter
# Amazon EC2 DL2q instance for cost-efficient, high-performance AI inference is now generally available
# How a Fervent Belief Split Silicon Valley—and Fueled the Blowup at OpenAI
# STEM And Sports Have Never Been Closer Together…
# CyberLink targeted in supply chain attack by infamous Lazarus hacking group
# Altman Back as OpenAI CEO Days After Being Fired
# What the events leading up to Sam Altman's reinstatement at OpenAI mean for the industry's future
# How the OpenAI ouster that wasn't is playing on K Street
# Sam Altman's ouster at OpenAI precipitated by letter to board about AI breakthrough, sources tell Reuters
# Sam Altman's ouster was precipitated by letter to board about AI breakthrough
# Windows Laptops at Best Buy from $130 + free shipping
# Windows may have a serious security problem on its hands
# Anouk Wipprecht’s 3D Printed LED Dress #WearableWednesday
# Exclusive-Sam Altman's ouster at OpenAI was precipitated by letter to board about AI breakthrough -sources
# Windows Hello auth bypassed on Microsoft, Dell, Lenovo laptops - BleepingComputer
# Meet OpenAI's All-Powerful Board That Pushed Out CEO Sam Altman
# US Mortgage Rates Slide Sharply, Reinvigorating Housing Demand
# Exclusive-Sam Altman's ouster at OpenAI was precipitated by letter to board about AI breakthrough -sources
# Sam Altman's ouster at OpenAI was precipitated by letter to board about AI breakthrough: Sources
# Sam Altman's ouster at OpenAI was precipitated by letter to board about AI breakthrough -sources
# How to give Windows Hello the finger and login as a user on their stolen laptop
# OpenAI and Microsoft hit with copyright lawsuit from non-fiction authors - Engadget
# 39 Best Walmart Black Friday Deals of 2023 to Shop Before They’re Gone
# 77 Best Black Friday Tech Deals (2023): Folding Phones, Laptops, Headphones
# Wall Street: +0.5% before Thanksgiving, November is perfect
# Microsoft’s Windows Hello fingerprint authentication easily bypassed by cybersecurity firm
# Sam Altman’s ouster shows Biden isn’t handling AI properly
# How Meta could benefit from the OpenAI shakeup
# N64 cult classic Jet Force Gemini releases on Nintendo Switch Online soon
# How Meta could benefit from the OpenAI shakeup
# Killer Instinct Anniversary Edition announced for $29.99; will replace Definitive Edition
# Microsoft To Build Four Data Centres Near Quebec City
# Godeal24 Black Friday Sales: Windows 11 keys από 7.5€, Office 2021 από 14.85€!
# Five days of chaos: What just happened at OpenAI?
# Top 10 SaaS Development Companies of 2023
# 1-Year Inflation Expectations Rise Whilst Some Traders Profited from Dovish Fed Bets
# Marketmind: Markets in a holiday mood
# Marketmind: Markets in a holiday mood
# : OpenAI rivals Google, Amazon make bids to take advantage of corporate soap opera
# HHW Gaming: The Best Black Friday Deals For Video Games & Consoles & Gaming Accessories
# What Is Dropper as a Service? The Delivery Service for Malware Developers
# MORNING BID ASIA-Markets in a holiday mood
# Taking Overvaluation To An Artificially High Level
# Dow Jones Up As Microsoft Pops On Sam Altman Return; Cathie Wood Sells This Leader Up 250%
# Steam's Autumn Sale: Diablo 4 Free Trial Live
# MICROSOFT CORP : RBC reiterates its Buy rating
# Sony accused of anti-competitive practices in UK courts, PlayStation digital policy under fire
# U.S. stocks higher at close of trade; Dow Jones Industrial Average up 0.53%
# Report: Next Call of Duty set in the Gulf War, Treyarch developing
# OpenAI says ousted CEO Sam Altman to return to company behind ChatGPT
# Stock Market Today: Dow closes higher as tech overcomes Nvidia slip
# Researchers find vulnerabilities in major laptop makers’ Windows Hello implementations
# What the events leading up to Sam Altman's reinstatement at OpenAI mean for the industry's future
# What the events leading up to Sam Altman's reinstatement at OpenAI mean for the industry's future
# What the events leading up to Sam Altman's reinstatement at OpenAI mean for the industry's future
# Google's Bard chatbot can now watch and offer info about YouTube video content
# Sam Altman’s Second Coming Sparks New Fears of the AI Apocalypse?
# Xbox Sales Plummet In Europe As PlayStation 5 Dominates: What's The Impact Of Exclusive Titles?
# Diamond Sleet supply chain compromise distributes a modified CyberLink installer | Microsoft Security Blog
# The Story Behind the Photo Everyone Knows
# Tech Advances on Clarity in AI Landscape -- Tech Roundup
# Dow Jones Up As Microsoft Pops On Sam Altman Return; Cathie Wood Sells This Leader Up 250%
# Create a Light-up Leaf necklace Quickly for your Thanksgiving Outfit #WearableWednesday
# Some OpenAI engineers make as much as $800,000 and were key players in Sam Altman's return
# Infleqtion Next Model is 100X GPT-4
# Bill Gates Says 3-Day Work Week Possible With AI
# Integrating Concur APIs with Excel using VBA
# SAP TechEd 2023 Through My Lens: SAP BTP reference architectures, use cases, collaboration, and fun-filled evenings with colleagues
# Bill Gates teases the possibility of a 3-day work week where ‘machines can make all the food and stuff’
# Open Sesame for OpenAI 2.0: How the Ctrl+Altman saga will play out in future
# How to Fix “There Was a Problem Resetting Your PC”
# CDKeylord Black Friday Sales: Windows 10 keys με 11€, Office με €18!
# Commentary: Sam Altman’s OpenAI return is a strategic win for Microsoft
# For Black Friday this refurbished Microsoft Surface Pro 6 is only $393.99
# U.S. stocks higher at close of trade; Dow Jones Industrial Average up 0.53%
# SAP TechEd Shenanigans: Tales of Tech, Learning & Frolics
# Are stocks telling us a pullback is ahead?
# The 52 best Black Friday 2023 tech deals you can shop right now
# Here’s who I’d cast in the inevitable OpenAI movie
# Preview: Top Drugstore Deals Next Week 11/26-12/2
# EU mulls wider scope for cybersecurity certification scheme
# OpenAI researchers warned board of AI breakthrough
# Forget about the Surface Pro 9, this Windows tablet is better and $160 cheaper this Black Friday
# I think Microsoft Azure “Eagle” is probably the most important tech news of 2023 that you haven't heard of — here's why
# OpenAI researchers warned board of AI breakthrough
# EU mulls wider scope for cybersecurity certification scheme - paper
# OpenAI researchers warned board of AI breakthrough
# Only the best Black Friday tech deals, as handpicked by TechSpot's staff
# OpenAI researchers warned board of AI breakthrough
# [XSX] Starfield - $70.36 (RRP $119.95) + Delivery ($0 Delivery with eBay Plus) @ The Gamesmen
# EU mulls wider scope for cybersecurity certification scheme - paper
# Fingerprint authentication is surprisingly easy to bypass - researchers find critical vulnerabilities in Windows Hello
# Cancer Council NSW lands new CIO
# University of Nevada Reno Newspapers, South Africa Magazines, Google Bard, More: Thursday Afternoon ResearchBuzz, November 23, 2023
# John Park’s Workshop returns next week
# 'Black Twitter' asks 'What if Sam Altman were a Black woman?' in the wake of ouster
# We can’t start this add-in because it isn’t set up properly in Office
# รับ Crazy M1neWorld Game - Microsoft Store th-TH
# django-microsoft-sso added to PyPI
# Viral Video Reveals ‘Harry Potter’ Remake Available on Disney+
# Possibility That an SEC Investigation of Altman and Nadella May Soon Be Filed
# Best Cyber Monday Deals 2023: 103+ sales from Amazon, Best Buy and More
# Can XRP Price Cross $10,000? Crypto Pundit Reveals How It’ll Happen
# Last minute Black Friday discounts on Xbox Game Pass subscriptions and Xbox gift cards is basically free money, but the sale is ending soon!
# Is the S&P 500 Broken?
# How to Fix Microsoft Compatibility Telemetry High CPU Usage
# Another way to botch the security analysis of Kyber-512
# Reflections on learning programming
# Tesla’s OG Roadster Is Going ‘Fully Open Source’ Including Design And Engineering
# Search Text Across Multiple Webpages in Opened Tabs with this Extension
# A quick look back at Microsoft's first sports video game: Microsoft Olympic Decathlon
# Does OpenAI's Origins Explain the Sam Altman Drama?
# Dell G16 12th-Gen i9 16" Gaming Laptop w/ GeForce RTX 3070 Ti for $1,450 + free shipping
# Dell G16 12th-Gen i9 16" Gaming Laptop w/ GeForce RTX 3070 Ti for $1,450 + free shipping
# Dell G16 12th-Gen i9 16" Gaming Laptop w/ GeForce RTX 3070 Ti for $1,450 + free shipping
# How to Turn off Website Recommendations in Windows 11
# Microsoft Bluetooth Mouse long-term review: Smart electronics, poor haptics
# Apple Employees Leave For Google More Than Any Other Tech Giant
# Apple Employees Leave For Google More Than Any Other Tech Giant
# The Window Layer – How GameBoy Graphics Work Part 4
# A 30-year Windows developer at Microsoft explains how the 'USB Cart of Death' featuring 60 daisy-chained USB devices taunted developers with BSODs
# 【Cyber Monday】超值之選 Microsoft Surface Pro 9 2022 版 39 折（限量）
# $900 OFF a Samsung Galaxy S23 Ultra?! The best phone since Windows Phone died is available for trade-in at a truly absurd price with this secret trick.
# Will Artificial Intelligence Bring About The End Of Smartphone Apps?
# Advertisers continue to flee Elon
# Twitter, Interactive Timelines, 3D Models, More: Saturday Afternoon ResearchBuzz, November 25, 2023
# Get all of Disney Plus and Hulu for just $2.99 a month — But act fast, this deal isn't going to last long
# This Black Friday laptop deal is perfect for both students and coders
# Microsoft Surface Pro 9 tablet with Core i7, 32GB RAM and 1TB SSD marked down by 31% on Amazon
# OpenAI's non-profit board took a stand. But this is Silicon Valley, and the billionaires won
# Exploring Interstellar Travel with J.G. Ballard, Captain Cook, Stansilaw Lem, and N. Katherine Hayles
# BlackRock meets with SEC over ETF, Binance’s new era begins and SBF loses release bid: Hodler’s Digest, Nov. 19-25
# Xbox Gift Card Deals in Walmart's Black Friday Sale
# McClellan: Could a St. Louisan be the most important person ever?
# 74 Best Buy Black Friday Deals to Shop Right Now (2023)
# Creepy Bill Gates Forecasts a 3 Day Workweek in the Age of AI
# AWS Reinvent Preview With Matt Wood, Who’s Been At AWS From The Start
# Elon Musk warns ‘something scared’ OpenAI chief scientist Ilya Sutskever as CEO Sam Altman’s return fails to answer key questions
# Price Dropped: Microsoft Office Pro 2019 + Windows 11 Pro now 87% off
# Windows Hello Fingerprint Authentication Vulnerability Exposed by Security Researchers
# North Korea-linked APT Lazarus is using a MagicLine4NX zero-day flaw in supply chain attack
# Sani plans skill acquisition city to train 1,600 youths
# Windows Push Notifications User Service High Memory or CPU usage
# Are you consistently candid, or like Sam Altman get shy in front of your board?
# Hold off on clicking 'buy' on that Nintendo Switch — the ROG Ally is the better choice this Black Friday and Cyber Monday
# The Sam Altman saga reveals the need for AI transparency
# Twitter's Advertiser Exodus Could Cost The Company $75 Million
# Twitter's Advertiser Exodus Could Cost The Company $75 Million
# 107° - Lenovo Legion Pro 7 16" WQXGA 240Hz 500Nit AMD 9 7945HX RTX 4090 (RTX 4080 £1693) 32GB RAM 512GB SSD No OS Laptop w/code (Possible 5-6% TCB)
# Elon Musk's X Could Lose Nearly $75 Million in Ad Revenue by Year-End: Report
# Super tiny Windows 11 OS that fits inside your 4GB thumb drive gets a big update — Tiny11 2311 shrinks 20% and allows cumulative updates
# Microsoft PC Manager 3.8.4.0 Beta
# Laptop refusing to boot from USB
# India Inc steps up focus on returning women professionals
# Why Alan Wake 2 deserves to win Game of the Year
# Coders, grab $500 off this powerful laptop before the Black Friday deals end
# Tiny11 2311 Fully Supports Windows 11 Version 23H2, Is Even Smaller
# X’s Advertiser Exodus Could Cost Platform $75 Million
# 微软更新 Microsoft 365 路线图：Copilot 近期亮相 Stream 应用、Teams 将内置“硬件商店”
# Here's the Top 10 Cyber Monday tech deals at Amazon, with many products 50% off or better!
# Which Mechanics Tool Set Should You Buy?
# US, UK, Japan, and other major powers sign AI security accord
# China building underwater data center with the power of 6 million PCs
# Cyber Monday: Snap up the Microsoft Surface Pro 8 for an all time low price at Amazon
# 10 Science Fiction and Fantasy Novels of 2023 to Check Out
# What is Geek Squad Scam Email? How to protect yourself?
# Business transformation is a journey. But what are the checkpoints?
# These Cyber Monday Laptop Deals Are Going to Save You So Much on Dell, Alienware, Lenovo, More
# These Cyber Monday Laptop Deals Are Going to Save You So Much on Dell, Alienware, Lenovo, More
# Crying out for a crisis
# Investing themes to watch in 2024: Magnificent 7, small caps, quick shifts, and more
# Investing themes to watch in 2024: Magnificent 7, small caps, quick shifts, and more
# Sunak welcomes foreign firms' £29.5bn 'vote of confidence'
# UK's Sunak hails $37 bln investments before FDI summit
# OpenAI Plans Share Sale Following Leadership Turmoil
# Microsoft Cyber Monday deals: Save on Surface, Office, and Xbox
# Warehouse Load Patterns – Part 1 – Requirements and General Patterns
# Microsoft, Uber, Dell CEOs Consider Government-Funded Stock Funds for Children
# Cyber Monday is your last chance for Xbox controller deals, and the best one has sold out at all but one retailer — so go quick
# Beyond Imagination: The Rise and Evolution of Generative AI Tools
# Report: OpenAI Researchers Warned Board of AI Significant Breakthrough Ahead of CEO’s Firing
# The 70 best Cyber Monday deals you can get from Amazon, Target and others
# How Dutch Clog Makers Are Keeping An 850-Year-Old Tradition Alive
# Refurb Acer Aspire Vero 12th-Gen. i7 14" Laptop w/ 1TB SSD for $423 in-cart + free shipping
# EU mulls wider scope for cyber security certification scheme
# EU mulls wider scope for cyber security certification scheme
# EU mulls wider scope for cyber security certification scheme
# EU mulls wider scope for cyber security certification scheme
# Increase collaboration and securely share cloud knowledge with AWS re:Post Private
# Use Amazon CloudWatch to consolidate hybrid, multicloud, and on-premises metrics
# Cyber Monday Deals To Kickstart Your Twitch, YouTube, Kick, Or Zoom Livestreams
# What are alternatives for lookmovie.io? Is it safe or a scam?
# Windows 11's lightweight version (Tiny11) gets even smaller and gains Windows Copilot via a new update
# Elon Musk's X may lose $75M by year's end amid advertiser flight: report
# What do you want from a smartphone case?
# Building Daleks with the UK Science Museum #SciFiSunday
# Xbox Gift Card Deals in Walmart's Cyber Monday Sale
# Best Buy Cyber Monday Deals 2023: TVs, Laptops, Headphones, More Sales
# Libreoffice Viewer снова в Google Play
# 154+ Best Cyber Monday Deals from Amazon, Best Buy, Walmart and More
# I bought this revolutionary Xbox controller at the lowest price we've ever seen it — here's why you should too
# Huge Best Buy Cyber Monday Sale: 95+ Deals I Recommend Right Now
# Samsung's Galaxy Buds 2 Pro are So Popular They're Back at 33% Off
# Updates about Database Projects for Microsoft Fabric
# Microsoft 365 Roadmap Weekly - Copilot in Stream is coming soon and more
# Escaping Duopoly: Best 5 Linux Smartphones Without Performance Security Excuses
# Religious wars in the tech industry.

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

results_headline = []
results_desc = []

for headline, desc in zip(df["Title"], df['Description']):
    # headline
#    try:
    pol_score_headline = SIA().polarity_scores(headline)  # run analysis
    pol_score_headline['Text'] = headline  # add text for viewing
    results_headline.append(pol_score_headline)
#    except:
#        print("Something went wrong, moving on!")
#        results_headline.append(None)
        
    # description
#    try:

    pol_score_desc = SIA().polarity_scores(str(desc))  # run analysis
    pol_score_desc['Text'] = desc  # add text for viewing
    results_desc.append(pol_score_desc)
#    except:
#        print("Something went wrong, moving on!")
#        results_desc.append(None)

        
len(results_headline)

# Print NaN values
for i, score in enumerate(pd.DataFrame(results_headline)['compound']):
    if pd.isna(score):
        print(f"Index: {i}, Headline: {df['Title'][i]}")

# %%
## results_desc

# %%
df = df.reset_index(drop=True)

# %%
# ADD TO DF
df['Score_headline'] = pd.DataFrame(results_headline)['compound']
df['Score_desc'] = pd.DataFrame(results_desc)['compound']

# %%
df
# Out:
#                                                  Title  \
# 0    The national security dimension of OpenAI's le...
# 1    OpenAI staff threaten mass exodus to join ex-C...
# 2    Sam Altman, ex OpenAI founder and CEO now at M...
# 3    BLUETTI Launches Black Friday Sale On Battery ...
# 4    What led to the OpenAI leadership shakeup and ...
# ..                                                 ...
# 349  Samsung's Galaxy Buds 2 Pro are So Popular The...
# 350  Updates about Database Projects for Microsoft ...
# 351  Microsoft 365 Roadmap Weekly - Copilot in Stre...
# 352  Escaping Duopoly: Best 5 Linux Smartphones Wit...
# 353               Religious wars in the tech industry.
#
#                                            Description            Source  \
# 0    Published on November 20, 2023 11:57 PM GMTAs ...     Lesswrong.com
# 1    SAN FRANCISCO: Hundreds of staff at OpenAI thr...               CNA
# 2    Microsoft has hired Sam Altman, where he will ...         TweakTown
# 3    Running out of power is nobody's idea of fun b...    redmondpie.com
# 4    Microsoft announced that it hired Sam Altman, ...        Biztoc.com
# ..                                                 ...               ...
# 349  Samsung's Galaxy Buds 2 Pro are popular ANC he...       Nextpit.com
# 350  comp A few weeks ago, I wrote a blog about Dat...      Red-gate.com
# 351  This week, the Microsoft 365 Roadmap added som...            Neowin
# 352  On November 8, 2018, Jeff Bezos, the multi-bil...  Nixsanctuary.com
# 353  In this post I continue to use MindBlog as my ...   Dericbownds.net
#
#            Published At  Score_headline  Score_desc
# 0   2023-11-20 23:57:17          0.0258      0.3041
# 1   2023-11-20 23:55:54         -0.1027     -0.6597
# 2   2023-11-20 23:55:02          0.6249      0.6249
# 3   2023-11-20 23:54:50          0.0000      0.4767
# 4   2023-11-20 23:54:06         -0.1531     -0.1280
# ..                  ...             ...         ...
# 349 2023-11-26 18:00:01          0.4754      0.5719
# 350 2023-11-26 17:39:47          0.0000     -0.5346
# 351 2023-11-26 17:30:01          0.0000      0.0000
# 352 2023-11-26 17:21:07          0.5210     -0.2124
# 353 2023-11-26 17:19:00         -0.5574     -0.2263
#
# [354 rows x 6 columns]
