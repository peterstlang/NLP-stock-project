# %% [markdown]
# # Testing an approach
# Found an article I would like to try out on my ms title/article dataset. Link can be found here: https://algotrading101.com/learn/sentiment-analysis-python-guide/

# %% [markdown]
# #### Reading data from file

# %%
# imports
import pandas as pd
# Out:
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
# C:\Users\peter\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# loading data
df = pd.read_csv("C:/Users/peter/Documents/NLP-stock-project/data/news_headlines.csv")
df.head()
# Out:
#                                                Title  \
# 0  The national security dimension of OpenAI's le...
# 1  OpenAI staff threaten mass exodus to join ex-C...
# 2  Sam Altman, ex OpenAI founder and CEO now at M...
# 3  BLUETTI Launches Black Friday Sale On Battery ...
# 4  What led to the OpenAI leadership shakeup and ...
#
#                                          Description          Source  \
# 0  Published on November 20, 2023 11:57 PM GMTAs ...   Lesswrong.com
# 1  SAN FRANCISCO: Hundreds of staff at OpenAI thr...             CNA
# 2  Microsoft has hired Sam Altman, where he will ...       TweakTown
# 3  Running out of power is nobody's idea of fun b...  redmondpie.com
# 4  Microsoft announced that it hired Sam Altman, ...      Biztoc.com
#
#            Published At
# 0  2023-11-20T23:57:17Z
# 1  2023-11-20T23:55:54Z
# 2  2023-11-20T23:55:02Z
# 3  2023-11-20T23:54:50Z
# 4  2023-11-20T23:54:06Z

# %%
df.shape
# Out:
# (82, 4)

# %%
#import
from langdetect import detect

# Adding a language column
df["Language"] = df["Title"].apply(lambda x: detect(x))
# Keeping only rows where lang is en
df = df.drop(df[df.Language != "en"].index)
df = df.drop("Language", axis=1)

# clean PublishedAt column
df["Published At"] = pd.to_datetime(df["Published At"], format="%Y-%m-%dT%H:%M:%SZ")

df.head()
# Out:
#                                                Title  \
# 0  The national security dimension of OpenAI's le...
# 1  OpenAI staff threaten mass exodus to join ex-C...
# 2  Sam Altman, ex OpenAI founder and CEO now at M...
# 3  BLUETTI Launches Black Friday Sale On Battery ...
# 4  What led to the OpenAI leadership shakeup and ...
#
#                                          Description          Source  \
# 0  Published on November 20, 2023 11:57 PM GMTAs ...   Lesswrong.com
# 1  SAN FRANCISCO: Hundreds of staff at OpenAI thr...             CNA
# 2  Microsoft has hired Sam Altman, where he will ...       TweakTown
# 3  Running out of power is nobody's idea of fun b...  redmondpie.com
# 4  Microsoft announced that it hired Sam Altman, ...      Biztoc.com
#
#          Published At
# 0 2023-11-20 23:57:17
# 1 2023-11-20 23:55:54
# 2 2023-11-20 23:55:02
# 3 2023-11-20 23:54:50
# 4 2023-11-20 23:54:06

# %%
# WHY IS DATA NOT PULLED AND SAVED?
df.shape
# Out:
# (77, 4)

# %%
for title in df["Title"]:
    print(title)
# Out:
# The national security dimension of OpenAI's leadership struggle
# OpenAI staff threaten mass exodus to join ex-CEO Sam Altman at Microsoft
# Sam Altman, ex OpenAI founder and CEO now at Microsoft to run new advanced AI intelligence team
# BLUETTI Launches Black Friday Sale On Battery Packs and A New Power Station
# What led to the OpenAI leadership shakeup and what it means for the future of AI
# Is Sam Altman joining Microsoft? Satya Nadella doesn’t seem to know
# Sam Altman’s OpenAI exit won’t stop the use of ChatGPT among crypto devs, at least for now
# Best free Language Translation websites
# Microsoft’s Nadella: OpenAI’s Governance Needs to Change
# How Microsoft’s Satya Nadella Kept the ‘Best Bromance in Tech’ Alive
# The Slatest for Nov. 20: Sam Altman’s Firing Is Just the First Skirmish in a War Over A.I.
# What’s next for the artificial intelligence industry?
# What led to the OpenAI leadership shakeup and what it means for the future of AI
# Kindle Scribe vs reMarkable 2: Which should you buy?
# Microsoft's Nadella: OpenAI's Governance Needs to Change
# Cramer says mergers and acquisitions could be the ‘potential savior’ for much of the market
# WLD Had a Wild Weekend—What's Next for Sam Altman's Worldcoin?
# Sam Altman says successful people ‘believe in themselves almost to the point of delusion’ —that's frightening, says expert
# Why OpenAI’s board ousted CEO Sam Altman and the fallout, explained
# Microsoft CEO says OpenAI governance needs to change no matter where Sam Altman ends up
# Sam Altman claims ‘still one team’ at OpenAI as investors, employees revolt over his ouster
# AI doomsayers blamed in OpenAI’s undoing
# The idea of OpenAI is dead. Now Microsoft is in the driver’s seat
# Court seems inclined to keep restricting Trump's trial speech. But gag order could be narrowed
# Microsoft CEO says OpenAI governance needs to change no matter where Sam Altman ends up
# Microsoft stock hits all-time high after hiring OpenAI’s fired CEO Sam Altman
# Sam Altman to join Microsoft research team after OpenAI ousts him. Here's what we know
# HP Pavilion TP01-3016 Desktop Computer, Intel Core i5-12400, 12GB Memory, 256GB SSD $389.99
# OpenAI's loss is Microsoft's gain: How the AI race just changed
# Microsoft CEO Nadella says OpenAI governance needs to change no matter where Altman ends up
# OpenAI's employees were given two explanations for why Sam Altman was fired. They're unconvinced and furious.
# Microsoft Hires Sam Altman as OpenAI's New CEO Vows to Investigate Firing
# OpenAI Investors Considering Suing Board After CEO's Firing: Sources
# Scattered Spider ransomware gang falls under government agency scrutiny
# OpenAI’s wild 60 hours: Here’s what happened
# Satya Nadella says “it's very clear that something has to change around the governance” of OpenAI no matter where Sam Altman ends up
# Microsoft CEO Nadella says OpenAI governance needs to change no matter where Altman ends up
# Microsoft is the only real winner in the OpenAI debacle
# How Music and Radio Played a Role During the American Indian Occupation of Alcatraz
# The Schism That Toppled Sam Altman
# The Good, Bad, And Ugly From Supercomputing ‘23, Or Nearby
# Microsoft CEO Nadella Says OpenAI Governance Needs To Change No Matter Where Altman Ends Up - CNBC
# Salesforce CEO Offers Jobs To Any OpenAI Researchers Who Resign
# 'Segregating high skill players from the population at large, forcing long wait times on them, is a form of discrimination': former Halo multiplayer lead on the 'failure' of SBMM in modern games
# OpenAI Turmoil Leaves Some CIOs Questioning the AI Powerhouse’s Future
# [Refurb] Microsoft Surface Laptop 2 i5 8th Gen 8Gb Ram 256Gb SSD $299 Delivered @ Australian Computer Traders
# The Microsoft Black Friday Ad Has Arrived: Save Hundreds on Surface Devices
# The Microsoft Black Friday Ad Has Arrived: Save Hundreds on Surface Devices
# Exclusive-OpenAI investors considering suing the board after CEO's abrupt firing - sources
# Exclusive-OpenAI investors considering suing the board after CEO's abrupt firing - sources
# Exclusive-OpenAI investors considering suing the board after CEO's abrupt firing - sources
# Why you should care about Sam Altman, Microsoft, and the OpenAI CEO mess
# Windows 10 22H2 Insider Release Preview Build 19045.3757 begins Copilot rollout
# OpenAI investors considering suing the board after CEO's abrupt firing: Sources
# Catch up on the OpenAI’s wild 60 hours… in 60 seconds | CNN Business
# Former Twitch CEO Emmett Shear is now leading OpenAI
# OpenAI investors considering suing the board after CEO's abrupt firing - sources
# Stock market news today: S&P 500, Nasdaq hit highest level since August as Nvidia, Microsoft reach records
# Marketmind: Rallying Nikkei on the cusp of a breakout
# Microsoft Advertising Shares Holiday Season Marketing Playbook via @sejournal, @kristileilani
# Satya Nadella And Microsoft Are The Biggest Winners Of The OpenAI Meltdown
# AI Doomsayers Blamed In OpenAI's Undoing
# Satya Nadella added $63 billion in market value for Microsoft with a ‘poker move for the ages’
# Israel battles Hamas near another Gaza hospital sheltering thousands
# Salesforce CEO Offers Jobs To Any OpenAI Researchers Who Resign
# Retro blinkenlights: driving 4 charlieplex LED matrices #AdafruitPlayground #FeaturedNote @Adafruit
# Microsoft CEO expected to negotiate stability at OpenAI and keep teams intact
# OpenAI’s new CEO Emmett Shear: AI is so dangerous, ‘it should cause you to s–t your pants’
# Why OpenAI blew up — and why it matters
# Don't expect competition authorities to wade into the Microsoft-OpenAI power-play -- yet | TechCrunch
# What’s going on with OpenAI now that Sam Altman is out?
# Washington watches as West Coast nerds fight for future of AI
# Sam Altman’s Move to Microsoft Changes Its Bing Search Battle With Google
# KB5033288: Following 23H2 and 22H2, Windows 11 21H2 gets improved WinRE as well
# US stocks jump as bond yields slip and Microsoft shares surge
# What to know about new OpenAI interim CEO Emmett Shear
# Analyst reaction to OpenAI turmoil: Shrewd move by Microsoft

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

results_headline = []
results_desc = []

for headline, desc in zip(df["Title"], df['Description']):
    # headline
#    try:
    pol_score_headline = SIA().polarity_scores(headline)  # run analysis
    pol_score_headline['Text'] = headline  # add text for viewing
    results_headline.append(pol_score_headline)
#    except:
#        print("Something went wrong, moving on!")
#        results_headline.append(None)
        
    # description
#    try:

    pol_score_desc = SIA().polarity_scores(str(desc))  # run analysis
    pol_score_desc['Text'] = desc  # add text for viewing
    results_desc.append(pol_score_desc)
#    except:
#        print("Something went wrong, moving on!")
#        results_desc.append(None)

        
len(results_headline)

# Print NaN values
for i, score in enumerate(pd.DataFrame(results_headline)['compound']):
    if pd.isna(score):
        print(f"Index: {i}, Headline: {df['Title'][i]}")

# %%
results_desc
# Out:
# [{'neg': 0.064,
#   'neu': 0.823,
#   'pos': 0.113,
#   'compound': 0.3041,
#   'Text': 'Published on November 20, 2023 11:57 PM GMTAs the very public custody battle over OpenAI\'s artificial intelligences winds down, I would like to point out a few facts, and then comment briefly on their possible significance.It has already been noticed that "at…'},
#  {'neg': 0.255,
#   'neu': 0.605,
#   'pos': 0.139,
#   'compound': -0.6597,
#   'Text': 'SAN FRANCISCO: Hundreds of staff at OpenAI threatened to quit the leading artificial intelligence company on Monday (Nov 20) and join Microsoft, deepening a crisis triggered by the shock'},
#  {'neg': 0.0,
#   'neu': 0.831,
#   'pos': 0.169,
#   'compound': 0.6249,
#   'Text': 'Microsoft has hired Sam Altman, where he will lead a new advanced artificial intelligence team, after OpenAI terminated him, then tried to rehire him. Continue reading at TweakTown >'},
#  {'neg': 0.047,
#   'neu': 0.85,
#   'pos': 0.103,
#   'compound': 0.4767,
#   'Text': "Running out of power is nobody's idea of fun because it can mean more than just not being able to watch TV or play a game — it can mean being unable to cook food or even losing all of the refrigerated food that you already have.\nThe post BLUETTI Launches Blac…"},
#  {'neg': 0.082,
#   'neu': 0.847,
#   'pos': 0.071,
#   'compound': -0.128,
#   'Text': 'Microsoft announced that it hired Sam Altman, the co-founder of ChatGPT maker OpenAI, after he was unexpectedly fired from that company days earlier. Microsoft is a financial partner in OpenAI. Altman had kicked off a global race for artificial intelligence s…'},
#  {'neg': 0.081,
#   'neu': 0.744,
#   'pos': 0.175,
#   'compound': 0.4404,
#   'Text': 'Microsoft CEO Satya Nadella doesn’t seem confident that Sam Altman will join the software giant. Nadella appeared on TV for two interviews about the OpenAI turmoil.'},
#  {'neg': 0.155,
#   'neu': 0.808,
#   'pos': 0.037,
#   'compound': -0.7876,
#   'Text': 'Former OpenAI CEO Sam Altman is associated with crypto by virtue of his founding role in Worldcoin — but his departure from AI powerhouse OpenAI has implications of its own. Altman was fired Friday after a boardroom coup caused by an alleged lack of candor wi…'},
#  {'neg': 0.0,
#   'neu': 0.752,
#   'pos': 0.248,
#   'compound': 0.926,
#   'Text': 'Sometimes, we must translate a text or a document into another language. In such a case, we look for tools to help us translate our text or document from one language into another for free. In this article, we will list some of the best free language translat…'},
#  {'neg': 0.0,
#   'neu': 0.912,
#   'pos': 0.088,
#   'compound': 0.4767,
#   'Text': 'Microsoft CEO Satya Nadella said that oversight of OpenAI needs to change after a dramatic weekend of events that began with the abrupt ouster of the artificial intelligence firm’s CEO, Sam Altman.#satyanadella #openai #samaltman'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': 'Sam Altman, left, an OpenAI co-founder, and Satya Nadella, the chief executive of Microsoft, in 2019, the year the companies began working together. Mr. Nadella moved fast to hire Sam Altman, who was pushed out of OpenAI on Friday, and asserted his company’s …'},
#  {'neg': 0.157,
#   'neu': 0.843,
#   'pos': 0.0,
#   'compound': -0.4215,
#   'Text': "Stories about anti-BDS legislation, Jezebel's legacy, a tip to reduce your turkey stress this Thanksgiving, and more."},
#  {'neg': 0.151,
#   'neu': 0.849,
#   'pos': 0.0,
#   'compound': -0.7964,
#   'Text': 'OpenAI, the company behind ChatGPT, ousted its CEO Sam Altman last week. Chaos ensued. Now, although Altman has already scored a job at Microsoft, most of OpenAI’s employees are threatening to quit if he isn’t reinstated. In this episode, we’ll talk about wha…'},
#  {'neg': 0.082,
#   'neu': 0.847,
#   'pos': 0.071,
#   'compound': -0.128,
#   'Text': 'Microsoft announced that it hired Sam Altman, the co-founder of ChatGPT maker OpenAI, after he was unexpectedly fired from that company days earlier. Microsoft is a financial partner in OpenAI. Altman had kicked off a global race for artificial intelligence s…'},
#  {'neg': 0.0,
#   'neu': 0.854,
#   'pos': 0.146,
#   'compound': 0.5574,
#   'Text': 'Debating the Kindle Scribe vs the reMarkable 2 for an e-ink tablet? Find out how they stack up for reading, writing, and drawing.'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': 'The Microsoft CEO said earlier Monday that he had hired ousted OpenAI CEO Sam Altman.'},
#  {'neg': 0.0,
#   'neu': 0.741,
#   'pos': 0.259,
#   'compound': 0.743,
#   'Text': 'CNBC\'s Jim Cramer on Monday told investors that more mergers could lead to stock gains outside of the "Magnificent Seven."'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': 'As the Altman and OpenAI drama unfolds, Worldcoin remains quiet.'},
#  {'neg': 0.095,
#   'neu': 0.775,
#   'pos': 0.13,
#   'compound': 0.25,
#   'Text': 'Ex-OpenAI CEO Sam Altman wrote in 2019 that "almost too much self-belief" was a key to success. That presents problems, says a UC Berkeley leadership expert.'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': 'Sam Altman has left ChatGPT creator OpenAI after a scuffle with its board. Here’s where the company stands now.'},
#  {'neg': 0.052,
#   'neu': 0.886,
#   'pos': 0.062,
#   'compound': 0.1263,
#   'Text': 'Microsoft CEO Satya Nadella told CNBC’s Jon Fortt on Monday that the governance structure of OpenAI needs to change, three days after the sudden firing CEO Sam Altman. “At this point, I think it’s very clear that something has to change around the governance,…'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': '“We are all going to work together some way or other, and I’m so excited,” Altman said.'},
#  {'neg': 0.109,
#   'neu': 0.83,
#   'pos': 0.061,
#   'compound': -0.34,
#   'Text': 'OpenAI has gone from ruling the world of artificial intelligence with ChatGPT to chaos, its chief executive ousted seemingly for advancing too fast and too far with the risky technology. The exit of Sam Altman set in motion a series of events that saw the ups…'},
#  {'neg': 0.102,
#   'neu': 0.752,
#   'pos': 0.146,
#   'compound': 0.5023,
#   'Text': 'But after Altman’s stunning ouster, followed by his apparent leap to Microsoft and a mutiny among OpenAI’s staff demanding his reinstatement, that idea is in shambles. And no one stands to benefit more than Microsoft, which can now work with Altman and potent…'},
#  {'neg': 0.073,
#   'neu': 0.899,
#   'pos': 0.027,
#   'compound': -0.4497,
#   'Text': "A federal appeals court appeared inclined Monday to reimpose at least some restrictions on Donald Trump's speech in his landmark election subversion case. But the judges wrestled with how to craft a gag order that doesn't infringe on the former president's fr…"},
#  {'neg': 0.082,
#   'neu': 0.918,
#   'pos': 0.0,
#   'compound': -0.34,
#   'Text': 'Microsoft CEO Satya Nadella told CNBC’s Jon Fortt on Monday that the governance structure of OpenAI needs to change, three days after the sudden firing CEO Sam Altman.'},
#  {'neg': 0.077,
#   'neu': 0.767,
#   'pos': 0.156,
#   'compound': 0.5267,
#   'Text': 'Microsoft stock jumped slightly Monday as a weekend fiasco landed the former CEO of the generative artificial intelligence startup OpenAI a high-level position at Microsoft, a saga that some analysts view as a positive for Microsoft despite the headaches. Mic…'},
#  {'neg': 0.0,
#   'neu': 0.923,
#   'pos': 0.077,
#   'compound': 0.4767,
#   'Text': 'It’s been a hectic weekend for OpenAI, the artificial intelligence company behind ChatGPT. The company’s board on Monday named a new interim CEO, three days after ousting co-founder Sam Altman from the position. And despite reports that executives and investo…'},
#  {'neg': 0.0,
#   'neu': 0.775,
#   'pos': 0.225,
#   'compound': 0.4404,
#   'Text': 'Good Home / Office Computer \n \nhttps://www.staples.com/hp-pavilion-tp01-3016-desktop-computer-intel-core-i5-12400-12gb-memory-256gb-ssd-577m9aa-aba/product_24538333 \n \n2.5GHz Intel Core i5-12400 hexa- ...'},
#  {'neg': 0.0,
#   'neu': 0.824,
#   'pos': 0.176,
#   'compound': 0.5994,
#   'Text': "With Sam Altman, OpenAI's former CEO, and friends landing at Microsoft, the Redmond crew is positioned to take over generative AI. The stock market agrees."},
#  {'neg': 0.076,
#   'neu': 0.798,
#   'pos': 0.126,
#   'compound': 0.3384,
#   'Text': 'Microsoft CEO Satya Nadella told CNBC\'s Jon Fortt on Monday that the governance structure of OpenAI needs to change, three days after the artificial intelligence startup suddenly fired CEO Sam Altman. "At this point, I think it\'s very clear that something has…'},
#  {'neg': 0.209,
#   'neu': 0.791,
#   'pos': 0.0,
#   'compound': -0.5719,
#   'Text': "During a late Sunday meeting, Ilya Sutskever relayed two explanations for Altman's ouster. They are furious."},
#  {'neg': 0.111,
#   'neu': 0.82,
#   'pos': 0.069,
#   'compound': -0.2263,
#   'Text': 'Microsoft snapped up Sam Altman and another architect of OpenAI for a new venture after their sudden departures shocked the artificial intelligence world, leaving the newly installed CEO of the ChatGPT maker to paper over tensions by vowing to investigate Alt…'},
#  {'neg': 0.0,
#   'neu': 0.933,
#   'pos': 0.067,
#   'compound': 0.1531,
#   'Text': "Some investors in OpenAI, makers of ChatGPT, are exploring legal recourse against the company's board, sources familiar with the matter told Reuters on Monday, after the board ousted CEO Sam Altman and sparked a potential mass exodus of employees."},
#  {'neg': 0.0,
#   'neu': 0.857,
#   'pos': 0.143,
#   'compound': 0.3612,
#   'Text': 'Ransomware group Scattered Spider aka Octo Tempest are masters at social engineering tactics like SIM swapping.'},
#  {'neg': 0.1,
#   'neu': 0.772,
#   'pos': 0.128,
#   'compound': 0.3384,
#   'Text': 'The artificial intelligence industry was shaken by tectonic shifts over the weekend. Sam Altman — the leader of one of the world’s most influential AI companies, OpenAI, and perhaps the most visible figure in the space — was fired Friday night by the startup’…'},
#  {'neg': 0.0,
#   'neu': 0.938,
#   'pos': 0.062,
#   'compound': 0.4391,
#   'Text': 'Microsoft CEO Satya Nadella told CNBC\'s Jon Fortt on Monday that the oversight of OpenAI needs to change. The comments come after days of drama kicked off by the OpenAI board dismissing co-founder Sam Altman as CEO. "At this point, I think it\'s very clear tha…'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'Text': nan},
#  {'neg': 0.145,
#   'neu': 0.855,
#   'pos': 0.0,
#   'compound': -0.5854,
#   'Text': 'OpenAI is in the process of fully collapsing on itself, following the ousting of former CEO Sam Altman in a shocking board decision. Exactly why the board decided to fire Altman is still unclear, but it seems increasingly likely that it was more about power-p…'},
#  {'neg': 0.0,
#   'neu': 0.864,
#   'pos': 0.136,
#   'compound': 0.7184,
#   'Text': 'It’s Native American Heritage Month and it wouldn’t be fair to celebrate it without also acknowledging some of the darker moments in Indigenous American history.54 years ago today, the Indians of All Tribes started their occupation of Alcatraz. Everardo Reyes…'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': 'Karen Hao and Charlie Warzel discuss the fracturing of OpenAI.'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': 'This year’s event was as much about AI as it was about HPC.'},
#  {'neg': 0.0,
#   'neu': 0.948,
#   'pos': 0.052,
#   'compound': 0.2577,
#   'Text': '(marketscreener.com) Microsoft Corp:\n * MICROSOFT CEO SATYA NADELLA SAYS WE WANT TO CONTINUE TO\nPARTNER\nWITH OPENAI - CNBC INTERVIEW\n * MICROSOFT CEO NADELLA SAYS OPEN TO PEOPLE STAYING AT\nOPENAI OR\nCOMING TO MICROSOFT\n * MICROSOFT CEO NADELLA SAYS OPENAI GOV…'},
#  {'neg': 0.107,
#   'neu': 0.826,
#   'pos': 0.067,
#   'compound': -0.2023,
#   'Text': 'Salesforce CEO Marc Benioff said Monday the software company will match the salary of any researcher who resigns from OpenAI, as over 700 employees of the embattled artificial intelligence company threaten to quit and follow ousted CEO Sam Altman to Microsoft…'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': 'Just how skill-based should skill-based matchmaking be?'},
#  {'neg': 0.0,
#   'neu': 0.95,
#   'pos': 0.05,
#   'compound': 0.25,
#   'Text': 'Microsoft said it is hiring Sam Altman to helm a new advanced artificial-intelligence research team, after his bid to return to OpenAI fell apart Sunday. Altman, left, appears onstage with Microsoft CEO Satya Nadella at OpenAI’s first developer conference, on…'},
#  {'neg': 0.042,
#   'neu': 0.958,
#   'pos': 0.0,
#   'compound': -0.2263,
#   'Text': 'Howdy\n\nWe have another limited surface offer for our Black Friday Sales\n\nThis time round we have the Surface Laptops 2.\n\nSurface Laptop 2\n\nIntel i5 8350u\n8Gb Ram\n256Gb SSD \n13.5” PixelSense™ Display\nWindows 11 Pro\n12 Month Warranty\n\nAll units are tested to a …'},
#  {'neg': 0.0,
#   'neu': 0.676,
#   'pos': 0.324,
#   'compound': 0.9531,
#   'Text': "From laptops to Xbox games to accessories, Microsoft's Black Friday sale is going strong and giving you a chance to shop early and save.\nIf you've been eyeing a Surface device, Black Friday is a great time to save on one of Microsoft's laptops or 2-in-1s. We …"},
#  {'neg': 0.0,
#   'neu': 0.676,
#   'pos': 0.324,
#   'compound': 0.9531,
#   'Text': "From laptops to Xbox games to accessories, Microsoft's Black Friday sale is going strong and giving you a chance to shop early and save.\nIf you've been eyeing a Surface device, Black Friday is a great time to save on one of Microsoft's laptops or 2-in-1s. We …"},
#  {'neg': 0.333,
#   'neu': 0.667,
#   'pos': 0.0,
#   'compound': -0.5423,
#   'Text': "Exclusive-OpenAI investors considering suing the board after CEO's abrupt firing - sources"},
#  {'neg': 0.0,
#   'neu': 0.89,
#   'pos': 0.11,
#   'compound': 0.1531,
#   'Text': "Some investors in OpenAI, makers of ChatGPT, are exploring legal recourse against the company's board, sources familiar with the matter told Reuters on..."},
#  {'neg': 0.0,
#   'neu': 0.934,
#   'pos': 0.066,
#   'compound': 0.1531,
#   'Text': "Some investors in OpenAI, makers of ChatGPT, are exploring legal recourse against the company's board, sources familiar with the matter told Reuters on Monday, after the board ousted\xa0CEO Sam Altman and sparked a potential mass exodus of employees.Sources said…"},
#  {'neg': 0.127,
#   'neu': 0.813,
#   'pos': 0.06,
#   'compound': -0.5423,
#   'Text': "None Sam Altman was forced out of his position as the CEO of OpenAI on Friday. • None The announcement kicked off a weekend of chaos involving Altman, Microsoft, and the firm behind ChatGPT. • None Here's why you should care, even if you aren't in the tech wo…"},
#  {'neg': 0.0,
#   'neu': 0.928,
#   'pos': 0.072,
#   'compound': 0.3612,
#   'Text': 'As promised, Microsoft is now rolling out a new Windows 10 Release Preview Build 19045.3757 to those members in the Windows Insider Program. It includes the rollout of the Copilot AI assistant. Read more...'},
#  {'neg': 0.0,
#   'neu': 0.934,
#   'pos': 0.066,
#   'compound': 0.1531,
#   'Text': "Some investors in OpenAI, makers of ChatGPT, are exploring legal recourse against the company's board, sources familiar with the matter told Reuters on Monday, after the directors ousted\xa0CEO Sam Altman and sparked a potential mass exodus of employees. Sources…"},
#  {'neg': 0.084,
#   'neu': 0.714,
#   'pos': 0.201,
#   'compound': 0.4215,
#   'Text': 'The artificial intelligence industry underwent was shaken by tectonic shifts over the weekend.'},
#  {'neg': 0.0,
#   'neu': 0.834,
#   'pos': 0.166,
#   'compound': 0.7992,
#   'Text': 'Twitch\xa0co-founder and former CEO Emmett Shear is taking the reins at OpenAI. If you’re not caught up on the OpenAI saga, here’s a good explainer. But the tl;dr is: this past Friday, OpenAI (the company responsible for generative AIs like ChatGPT and DALL-E) a…'},
#  {'neg': 0.0,
#   'neu': 0.934,
#   'pos': 0.066,
#   'compound': 0.1531,
#   'Text': "(marketscreener.com) Some investors in OpenAI, makers of\nChatGPT, are exploring legal recourse against the company's\nboard, sources familiar with the matter told Reuters on Monday,\nafter the board ousted CEO Sam Altman and sparked a potential\nmass exodus of e…"},
#  {'neg': 0.0,
#   'neu': 0.797,
#   'pos': 0.203,
#   'compound': 0.8481,
#   'Text': 'Stocks closed in the green on Monday, after notching their third straight week of wins as hopes for a retreat in US interest-rate hikes persisted. The S&P 500 (^GSPC) closed up 0.7%, while the Dow Jones Industrial Average (^DJI) climbed more than 0.5%, or abo…'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': 'Marketmind: Rallying Nikkei on the cusp of a breakout'},
#  {'neg': 0.0,
#   'neu': 0.601,
#   'pos': 0.399,
#   'compound': 0.9393,
#   'Text': "Discover Microsoft Advertising's insights for maximizing holiday sales from its free 30-page Festive Holiday Marketing Playbook. \nThe post Microsoft Advertising Shares Holiday Season Marketing Playbook appeared first on Search Engine Journal."},
#  {'neg': 0.0,
#   'neu': 0.855,
#   'pos': 0.145,
#   'compound': 0.5984,
#   'Text': 'As OpenAI imploded, Satya Nadella appeared to pull off one of the one of the tech industry’s most remarkable acquihires — without an actual acquisition.'},
#  {'neg': 0.154,
#   'neu': 0.758,
#   'pos': 0.087,
#   'compound': -0.34,
#   'Text': 'OpenAI has gone from ruling the world of artificial intelligence with ChatGPT to chaos, its chief executive ousted seemingly for advancing too fast and too far with the risky technology.'},
#  {'neg': 0.043,
#   'neu': 0.86,
#   'pos': 0.097,
#   'compound': 0.3612,
#   'Text': 'Following the ouster of CEO Sam Altman, the future of OpenAI is in question and the ultimate repercussions unclear. With a majority of OpenAI employees poised to jump ship and follow Altman to Microsoft, the startup that brought the world ChatGPT looks like a…'},
#  {'neg': 0.124,
#   'neu': 0.876,
#   'pos': 0.0,
#   'compound': -0.6249,
#   'Text': 'Israeli forces pressed their offensive against Hamas in northern Gaza on Monday, battling militants around a hospital where thousands of patients and displaced people have been sheltering for weeks, and where health officials called for the evacuation of the …'},
#  {'neg': 0.211,
#   'neu': 0.789,
#   'pos': 0.0,
#   'compound': -0.5859,
#   'Text': 'Over 700 OpenAI employees have signed a letter saying they will leave the company after its Board fired CEO Sam Altman.'},
#  {'neg': 0.0,
#   'neu': 0.886,
#   'pos': 0.114,
#   'compound': 0.5423,
#   'Text': 'I recently released another retrocomputer miniature that incorporates a handful of Adafruit boards so I thought that I’d share the details here. The original Connection Machines were built in the late 80s and early 90s to provide a few thousand hyper-connecte…'},
#  {'neg': 0.068,
#   'neu': 0.74,
#   'pos': 0.192,
#   'compound': 0.6369,
#   'Text': "OpenAI's board of directors fired Sam Altman, triggering massive pushback from workers, but Microsoft CEO Satya Nadella is expected to help calm the storm. Continue reading at TweakTown >"},
#  {'neg': 0.118,
#   'neu': 0.841,
#   'pos': 0.04,
#   'compound': -0.6238,
#   'Text': 'As someone who works in one of the many industries that AI looks set to decimate, it’s probably no surprise that I find myself constantly …\nThe post OpenAI’s new CEO Emmett Shear: AI is so dangerous, ‘it should cause you to s–t your pants’ appeared first on B…'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'Text': '9 questions about OpenAI’s wild weekend, answered.'},
#  {'neg': 0.109,
#   'neu': 0.717,
#   'pos': 0.174,
#   'compound': 0.34,
#   'Text': 'As the tech world watches Microsoft suck in top execs and AI engineering talent from OpenAI, the generative AI giant in which it already holds a minority As the tech world watches Microsoft suck in top execs and AI engineering talent from OpenAI, one question…'},
#  {'neg': 0.0,
#   'neu': 0.873,
#   'pos': 0.127,
#   'compound': 0.6597,
#   'Text': 'Over the course of a dramatic three days for the booming artificial intelligence industry, prominent AI leader Sam Altman was ousted from ChatGPT-maker OpenAI, the company he co-founded — then quickly hired by its largest investor, Microsoft. Tech is not your…'},
#  {'neg': 0.104,
#   'neu': 0.792,
#   'pos': 0.104,
#   'compound': 0.0,
#   'Text': 'Early reports on the OpenAI rift indicate that what looks like a business argument is actually wrapped up in an ideological schism.'},
#  {'neg': 0.0,
#   'neu': 0.795,
#   'pos': 0.205,
#   'compound': 0.8074,
#   'Text': "While Microsoft's swift hiring of Sam Altman could boost its position as the frontrunner in the race of AI, there are unintended consequences that will benefit Google's position in AI dominance, industry analysts tell Adweek. Altman's move to Microsoft capped…"},
#  {'neg': 0.0,
#   'neu': 0.847,
#   'pos': 0.153,
#   'compound': 0.6597,
#   'Text': 'Microsoft released a Dynamic Update package (KB5033288) for Windows 11 21H2 this past week, following the ones for versions 22H2 and 23H2. The update improves the Windows 11 WinRE and more. Read more...'},
#  {'neg': 0.032,
#   'neu': 0.84,
#   'pos': 0.128,
#   'compound': 0.7011,
#   'Text': 'None Stocks soared Monday as as bond yields slipped and Microsoft stock surged to a new high. • None The 10-year Treasury yield eased two basis points to 4.42%. • None The Dow and S&P 500 are headed for their best monthly performance in over a year. US stocks…'},
#  {'neg': 0.144,
#   'neu': 0.856,
#   'pos': 0.0,
#   'compound': -0.7845,
#   'Text': 'Shear, the former CEO of Twitch, fears an AI-related disaster. OpenAI was thrown into upheaval in recent days after the sudden departure of CEO Sam Altman, who just three days later landed at Microsoft. The ouster elicited a letter from about 600 employees at…'},
#  {'neg': 0.031,
#   'neu': 0.969,
#   'pos': 0.0,
#   'compound': -0.0516,
#   'Text': 'The trick now for Microsoft Corp. will be navigating its continuing business relationship with OpenAI while at the same time harboring its exiled leadership members, says Brian Jackson, principal research director at Info-Tech Research Group, following the st…'}]

# %%
df = df.reset_index(drop=True)

# %%
# ADD TO DF
df['Score_headline'] = pd.DataFrame(results_headline)['compound']
df['Score_desc'] = pd.DataFrame(results_desc)['compound']

# %%
df
# Out:
#                                                 Title  \
# 0   The national security dimension of OpenAI's le...
# 1   OpenAI staff threaten mass exodus to join ex-C...
# 2   Sam Altman, ex OpenAI founder and CEO now at M...
# 3   BLUETTI Launches Black Friday Sale On Battery ...
# 4   What led to the OpenAI leadership shakeup and ...
# ..                                                ...
# 72  Sam Altman’s Move to Microsoft Changes Its Bin...
# 73  KB5033288: Following 23H2 and 22H2, Windows 11...
# 74  US stocks jump as bond yields slip and Microso...
# 75  What to know about new OpenAI interim CEO Emme...
# 76  Analyst reaction to OpenAI turmoil: Shrewd mov...
#
#                                           Description           Source  \
# 0   Published on November 20, 2023 11:57 PM GMTAs ...    Lesswrong.com
# 1   SAN FRANCISCO: Hundreds of staff at OpenAI thr...              CNA
# 2   Microsoft has hired Sam Altman, where he will ...        TweakTown
# 3   Running out of power is nobody's idea of fun b...   redmondpie.com
# 4   Microsoft announced that it hired Sam Altman, ...       Biztoc.com
# ..                                                ...              ...
# 72  While Microsoft's swift hiring of Sam Altman c...       Biztoc.com
# 73  Microsoft released a Dynamic Update package (K...           Neowin
# 74  None Stocks soared Monday as as bond yields sl...       Biztoc.com
# 75  Shear, the former CEO of Twitch, fears an AI-r...       Biztoc.com
# 76  The trick now for Microsoft Corp. will be navi...  IT World Canada
#
#           Published At  Score_headline  Score_desc
# 0  2023-11-20 23:57:17          0.0258      0.3041
# 1  2023-11-20 23:55:54         -0.1027     -0.6597
# 2  2023-11-20 23:55:02          0.6249      0.6249
# 3  2023-11-20 23:54:50          0.0000      0.4767
# 4  2023-11-20 23:54:06         -0.1531     -0.1280
# ..                 ...             ...         ...
# 72 2023-11-20 22:12:08         -0.3818      0.8074
# 73 2023-11-20 22:12:02          0.6369      0.6597
# 74 2023-11-20 22:10:08          0.2960      0.7011
# 75 2023-11-20 22:08:06          0.0000     -0.7845
# 76 2023-11-20 22:08:01         -0.3612     -0.0516
#
# [77 rows x 6 columns]
